# %% [markdown]
# # Exploratory Text Analysis
#
# ## What kinds of text analysis are there?
#
# * analyst knows the pattern
#     * regular expressions
# * analyst does not know the pattern
#     * natural language processing
#         * compares historical examples to judge novel cases
#             * comparisons are statistical and approximate

# %%
# [a-zA-Z]{3}[ ]?[0-9]{4} -> 3 letters of any case, followed by 1 space (optional), followed by 4 nums!
# ?      means 0 or 1 occurance
# +      means 1 or more occurance
# *      means 0 or more occurance
# ^      means start of the pattern
# $      means end of the pattern

# %% [markdown]
# ### Examples of Analysis

# %% [markdown]
# When you know the pattern:

# %%
pattern = '£ ?[0-9][0-9]?' # £ then SPACE-optional then digit then digit-optional

document = 'My eggs cost £ 3, bread cost £2, vodka cost £ 35'

# %%
import re

# %%
re.findall(pattern, document)
# Out:
# ['£ 3', '£2', '£ 35']

# %% [markdown]
# If you dont:
#
# * sentiment analysis
#     * how positive/negative is this (new) review?
# * topic analysis
#     * what is this document about?

# %% [markdown]
# ## What can I do if I know what pattern I want to find?
#
# * finding ("extracting")
#     * what matches the pattern?
# * matching ("validating")
#     * does the entire document match YES/NO?
# * substitue ("replacing")
#     * replace a part that matches a pattern with another...

# %% [markdown]
# ## How do I validate text with pandas?

# %%
import pandas as pd

# %%
ti = pd.read_csv('https://raw.githubusercontent.com/a-forty-two/diamler_17_jan/main/titanic.csv')
ti.sample(2)
# Out:
#      survived  pclass   sex   age  sibsp  parch   fare embarked  class  who  \
# 846         0       3  male   NaN      8      2  69.55        S  Third  man
# 724         1       1  male  27.0      1      0  53.10        S  First  man
#
#      adult_male deck  embark_town alive  alone
# 846        True  NaN  Southampton    no  False
# 724        True    E  Southampton   yes  False

# %%
ti['ticket'] = "Ticket: " + ti['class'] + "; Price: $ " + ti['fare'].astype(str) + "; Port: " + ti['embark_town'] + ";"

# %%
ti[['class', 'fare', 'embark_town', 'ticket']].head(3)
# Out:
#    class     fare  embark_town  \
# 0  Third   7.2500  Southampton
# 1  First  71.2833    Cherbourg
# 2  Third   7.9250  Southampton
#
#                                               ticket
# 0   Ticket: Third; Price: $ 7.25; Port: Southampton;
# 1  Ticket: First; Price: $ 71.2833; Port: Cherbourg;
# 2  Ticket: Third; Price: $ 7.925; Port: Southampton;

# %%
pattern = '(First|Second)'

ti['class'].str.match(pattern)
# Out:
# 0      False
# 1       True
# 2      False
# 3       True
# 4      False
#        ...
# 886     True
# 887     True
# 888    False
# 889     True
# 890    False
# Name: class, Length: 891, dtype: bool

# %%
ti.loc[ ti['class'].str.match(pattern)  , 'survived'].mean()
# Out:
# 0.5575

# %%
pattern = '(Third)'
ti.loc[ ti['class'].str.match(pattern)  , 'survived'].mean()
# Out:
# 0.24236252545824846

# %% [markdown]
# ## How do I extract data with pandas?

# %%
ti[['class', 'fare', 'embark_town', 'ticket']].head(3)
# Out:
#    class  ...                                             ticket
# 0  Third  ...   Ticket: Third; Price: $ 7.25; Port: Southampton;
# 1  First  ...  Ticket: First; Price: $ 71.2833; Port: Cherbourg;
# 2  Third  ...  Ticket: Third; Price: $ 7.925; Port: Southampton;
#
# [3 rows x 4 columns]

# %%
#just for demo, no real purpose
pattern = '([0-9.]+)'

ti['ticket'].str.extract(pattern).sample(4)
# Out:
#            0
# 848     33.0
# 869  11.1333
# 405     21.0
# 651     23.0

# %% [markdown]
# ## How do I substitue text with pandas?

# %%
ti['ticket'].str.replace('$', '€').sample(1)
# Out:
# 430    Ticket: First; Price: € 26.55; Port: Southampton;
# Name: ticket, dtype: object

# %% [markdown]
# ## What are regular expressions?

# %% [markdown]
# Regular expressions are a language for describing patterns in text.
#
# They are separate from python, but may be used within python program. (And elsewhere, eg., often in SQL).
#
# They are notoriously difficult to read and write; and as a separate language, an additional tool to learn.

# %% [markdown]
# ## What regular expression patterns can I use?
#
# * literals
#     * `a`, find me an `a`
#     * `£`, find `£`
#     * `!` means `!`
#     * ... most symbols mean "find me"
# * `.`
#     * find any **single** symbol
# * character classes -- find a **single** symbol
#     * `[abc]` $\rightarrow$ **either** a, b, c
#     * `[0-9]` $\rightarrow$ **either** 0, 1, 2, 3,...9
#     * `[A-Z]` $\rightarrow$ **either** capital A, B, ... Z
#     * inversions
#         * `[^abc]` $\rightarrow$ **is not** `a` OR `b` OR `c`
#         * `[^a-zA-Z0-9 ]`  $\rightarrow$ **is not** alphanumeric-ish
#
# * alternatives -- find the character**s** given by...
#     * `(May|June|July)`  $\rightarrow$ **the whole worlds** May OR June..

# %%
ti['ticket'].str.extract('(Ticket: (First|Second))')

# %%
ti['ticket'].str.extract('( [0-9][0-9])')

# %%
ti['ticket'].sample(1)

# %%
ti['ticket'].str.extract('(Ticket: [A-Z])').sample(2)

# %%
ti['ticket'].str.extract('(T........)').sample(3)

# %%
ti['ticket'].str.extract('(Price: [^0-9A-Za-z] ..)').sample(3)

# %%
ti['ticket'].str.extract('(Port: (Cherbourg|Southampton))').sample(3)

# %% [markdown]
# * repetitions
#     * optional `?`
#         * an optional number: `[0-9]?`
#     * one or more `+`
#         * one or more spaces: ` +`
#     * optional, or more, `*`
#         * ` [0-9][0-9]?.[0-9]*`

# %%
ti['ticket'].str.extract('([0-9][0-9]?.[0-9]*)').sample(3)

# %%
ti['ticket'].str.extract('(Ticket: [a-zA-Z]+)').sample(3)

# %%
row = 0
match = 1 # second match

ti['ticket'].str.extractall('([a-zA-Z]+: [a-zA-Z]+)').loc[row, match]

# %%
ti['ticket'].str.extract('([a-zA-Z]+tow?n)')

# %% [markdown]
# * EXTRA:
#     * escaping
#         * How do I say, literally, the `.` symbol?
#         * `\.`

# %%
ti['ticket'].str.extract('(\$ [0-9]+\.[0-9]+)').sample(2)

# %% [markdown]
# * positional matching
#     * `^` means **at the beginning**
#     * `$` means **at the end**

# %%
ti['ticket'].str.extractall('([a-zA-Z]+: [a-zA-Z]+;$)').sample(1)

# %%
ti['ticket'].str.extractall('(^[a-zA-Z]+: [a-zA-Z]+;)').sample(1)
# Out:
#                       0
#   match
# 2 0      Ticket: Third;

# %% [markdown]
# ## Next Steps
#
# * review a "Regex Cheat Sheet"
#     * also, eg., https://en.wikipedia.org/wiki/Regular_expression#Examples

# %% [markdown]
# ## Exercise (30 min)
#
# * find all the words in the tickets
#     * HINT: a word is a repeated letter followed by a space or a colon
#     * HINT: `[ :]` means a space or a colon
# * find all the USD prices
#     * HINT: ``` \$ ``` and repeated numbers
#
# * find all the high-price tickets
#     * HINT: consider `\$`, tripple-digit number, `\.`

# %%
#Solution
ti.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone  \
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True
#
#                                               ticket
# 0   Ticket: Third; Price: $ 7.25; Port: Southampton;
# 1  Ticket: First; Price: $ 71.2833; Port: Cherbourg;
# 2  Ticket: Third; Price: $ 7.925; Port: Southampton;
# 3   Ticket: First; Price: $ 53.1; Port: Southampton;
# 4   Ticket: Third; Price: $ 8.05; Port: Southampton;

# %%
ti['ticket'].str.findall('([a-zA-Z]+[ :])')
# Out:
# 0      [Ticket:, Price:, Port:]
# 1      [Ticket:, Price:, Port:]
# 2      [Ticket:, Price:, Port:]
# 3      [Ticket:, Price:, Port:]
# 4      [Ticket:, Price:, Port:]
#                  ...
# 886    [Ticket:, Price:, Port:]
# 887    [Ticket:, Price:, Port:]
# 888    [Ticket:, Price:, Port:]
# 889    [Ticket:, Price:, Port:]
# 890    [Ticket:, Price:, Port:]
# Name: ticket, Length: 891, dtype: object

# %%
ticket_word_list= list(ti['ticket'].str.findall('([a-zA-Z]+[ :])').dropna())

print(ticket_word_list)
# Out:
# [['Ticket:', 'Price:', 'Port:'], ['Ticket:', 'Price:', 'Port:'], ['Ticket:', 'Price:', 'Port:'], ['Ticket:', 'Price:', 'Port:'], ['Ticket:', 'Price:', 'Port:'], ['Ticket:', 'Price:', 'Port:'], ['Ticket:', 'Price:', 'Port:'], ['Ticket:', 'Price:', 'Port:'], ['Ticket:', 'Price:', 'Port:'], ['Ticket:', 'Price:', 'Port:'], ['Ticket:', 'Price:', 'Port:'], ['Ticket:', 'Price:', 'Port:'], ['Ticket:', 'Price:', 'Port:'], ['Ticket:', 'Price:', 'Port:'], ['Ticket:', 'Price:', 'Port:'], ['Ticket:', 'Price:', 'Port:'], ['Ticket:', 'Price:', 'Port:'], ['Ticket:', 'Price:', 'Port:'], ['Ticket:', 'Price:', 'Port:'], ['Ticket:', 'Price:', 'Port:'], ['Ticket:', 'Price:', 'Port:'], ['Ticket:', 'Price:', 'Port:'], ['Ticket:', 'Price:', 'Port:'], ['Ticket:', 'Price:', 'Port:'], ['Ticket:', 'Price:', 'Port:'], ['Ticket:', 'Price:', 'Port:'], ['Ticket:', 'Price:', 'Port:'], ['Ticket:', 'Price:', 'Port:'], ['Ticket:', 'Price:', 'Port:'], ['Ticket:', 'Price:', 'Port:'], ['Ticket:', 'Price:', 'Port:'], ['Ticket:', 'Price:', 'Port:'], ['Ticket:', 'Price:', 'Port:'], ['Ticket:', 'Price:', 'Port:'], ['Ticket:', 'Price:', 'Port:'], ['Ticket:', 'Price:', 'Port:'], ['Ticket:', 'Price:', 'Port:'], ['Ticket:', 'Price:', 'Port:'], ['Ticket:', 'Price:', 'Port:'], ['Ticket:', 'Price:', 'Port:'], ['Ticket:', 'Price:', 'Port:'], ['Ticket:', 'Price:', 'Port:'], ['Ticket:', 'Price:', 'Port:'], ['Ticket:', 'Price:', 'Port:'], ['Ticket:', 'Price:', 'Port:'], ['Ticket:', 'Price:', 'Port:'], ['Ticket:', 'Price:', 'Port:'], ['Ticket:', 'Price:', 'Port:'], ['Ticket:', 'Price:', 'Port:'], ['Ticket:', 'Price:', 'Port:'], ['Ticket:', 'Price:', 'Port:'], ['Ticket:', 'Price:', 'Port:'], ['Ticket:', 'Price:', 'Port:'], ['Ticket:', 'Price:', 'Port:'], ['Ticket:', 'Price:', 'Port:'], ['Ticket:', 'Price:', 'Port:'], ['Ticket:', 'Price:', 'Port:'], ['Ticket:', 'Price:', 'Port:'], ['Ticket:', 'Price:', 'Port:'], ['Ticket:', 'Price:', 'Port:'], ['Ticket:', 'Price:', 'Port:'], ['Ticket:', 'Price:', 'Port:'], ['Ticket:', 'Price:', 'Port:'], ['Ticket:', 'Price:', 'Port:'], ['Ticket:', 'Price:', 'Port:'], ['Ticket:', 'Price:', 'Port:'], ['Ticket:', 'Price:', 'Port:'], ['Ticket:', 'Price:', 'Port:'], ['Ticket:', 'Price:', 'Port:'], ['Ticket:', 'Price:', 'Port:'], ['Ticket:', 'Price:', 'Port:'], ['Ticket:', 'Price:', 'Port:'], ['Ticket:', 'Price:', 'Port:'], ['Ticket:', 'Price:', 'Port:'], ['Ticket:', 'Price:', 'Port:'], ['Ticket:', 'Price:', 'Port:'], ['Ticket:', 'Price:', 'Port:'], ['Ticket:', 'Price:', 'Port:'], ['Ticket:', 'Price:', 'Port:'], ['Ticket:', 'Price:', 'Port:'], ['Ticket:', 'Price:', 'Port:'], ['Ticket:', 'Price:', 'Port:'], ['Ticket:', 'Price:', 'Port:'], ['Ticket:', 'Price:', 'Port:'], ['Ticket:', 'Price:', 'Port:'], ['Ticket:', 'Price:', 'Port:'], ['Ticket:', 'Price:', 'Port:'], ['Ticket:', 'Price:', 'Port:'], ['Ticket:', 'Price:', 'Port:'], ['Ticket:', 'Price:', 'Port:'], ['Ticket:', 'Price:', 'Port:'], ['Ticket:', 'Price:', 'Port:'], ['Ticket:', 'Price:', 'Port:'], ['Ticket:', 'Price:', 'Port:'], ['Ticket:', 'Price:', 'Port:'], ['Ticket:', 'Price:', 'Port:'], ['Ticket:', 'Price:', 'Port:'], ['Ticket:', 'Price:', 'Port:'], ['Ticket:', 'Price:', 'Port:'], ['Ticket:', 'Price:', 'Port:'], ['Ticket:', 'Price:', 'Port:'], ['Ticket:', 'Price:', 'Port:'], ['Ticket:', 'Price:', 'Port:'], ['Ticket:', 'Price:', 'Port:'], ['Ticket:', 'Price:', 'Port:'], ['Ticket:', 'Price:', 'Port:'], ['Ticket:', 'Price:', 'Port:'], ['Ticket:', 'Price:', 'Port:'], ['Ticket:', 'Price:', 'Port:'], ['Ticket:', 'Price:', 'Port:'], ['Ticket:', 'Price:', 'Port:'], ['Ticket:', 'Price:', 'Port:'], ['Ticket:', 'Price:', 'Port:'], ['Ticket:', 'Price:', 'Port:'], ['Ticket:', 'Price:', 'Port:'], ['Ticket:', 'Price:', 'Port:'], ['Ticket:', 'Price:', 'Port:'], ['Ticket:', 'Price:', 'Port:'], ['Ticket:', 'Price:', 'Port:'], ['Ticket:', 'Price:', 'Port:'], ['Ticket:', 'Price:', 'Port:'], ['Ticket:', 'Price:', 'Port:'], ['Ticket:', 'Price:', 'Port:'], ['Ticket:', 'Price:', 'Port:'], ['Ticket:', 'Price:', 'Port:'], ...

# %%
wordset=set(ticket_word_list[0])

# %%
import re
words=[]
for word in wordset:
    word=re.findall("[a-zA-Z]+", word)
    # words.append("".join(word))
    words.append(word[0])
print(words)
# Out:
# ['Port', 'Ticket', 'Price']

# %%
ti['ticket'].str.extract('(\$ [0-9]+\.[0-9]+)')
# Out:
#              0
# 0       $ 7.25
# 1    $ 71.2833
# 2      $ 7.925
# 3       $ 53.1
# 4       $ 8.05
# ..         ...
# 886     $ 13.0
# 887     $ 30.0
# 888    $ 23.45
# 889     $ 30.0
# 890     $ 7.75
#
# [891 rows x 1 columns]

# %%
ti['price']=ti['ticket'].str.extract('(\$ [0-9]+\.[0-9]+)').replace('\$ ',"",regex=True).astype('float')

# %%
# ti['price']=ti['price'].str.replace('\$ ',"",regex=True).astype('float')

ti.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone  \
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True
#
#                                               ticket    price
# 0   Ticket: Third; Price: $ 7.25; Port: Southampton;   7.2500
# 1  Ticket: First; Price: $ 71.2833; Port: Cherbourg;  71.2833
# 2  Ticket: Third; Price: $ 7.925; Port: Southampton;   7.9250
# 3   Ticket: First; Price: $ 53.1; Port: Southampton;  53.1000
# 4   Ticket: Third; Price: $ 8.05; Port: Southampton;   8.0500

# %%
ti['price'].max()
# Out:
# 512.3292

# %%
ti.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone     ticket    price
# 0    man        True  NaN  Southampton    no  False     $ 7.25   7.2500
# 1  woman       False    C    Cherbourg   yes  False  $ 71.2833  71.2833
# 2  woman       False  NaN  Southampton   yes   True    $ 7.925   7.9250
# 3  woman       False    C  Southampton   yes  False     $ 53.1  53.1000
# 4    man        True  NaN  Southampton    no   True     $ 8.05   8.0500

# %%
row = 0
match = 1 # second match
# ti['ticket'].str.extractall('(\$ [0-9][0-9][0-9]+\.[0-9]+)')#.loc[row, 0]

ti.sort_values(by="price",ascending=False)
# Out:
#      survived  pclass     sex   age  sibsp  parch      fare embarked   class  \
# 258         1       1  female  35.0      0      0  512.3292        C   First
# 737         1       1    male  35.0      0      0  512.3292        C   First
# 679         1       1    male  36.0      0      1  512.3292        C   First
# 341         1       1  female  24.0      3      2  263.0000        S   First
# 27          0       1    male  19.0      3      2  263.0000        S   First
# ..        ...     ...     ...   ...    ...    ...       ...      ...     ...
# 806         0       1    male  39.0      0      0    0.0000        S   First
# 481         0       2    male   NaN      0      0    0.0000        S  Second
# 597         0       3    male  49.0      0      0    0.0000        S   Third
# 61          1       1  female  38.0      0      0   80.0000      NaN   First
# 829         1       1  female  62.0      0      0   80.0000      NaN   First
#
#        who  adult_male deck  embark_town alive  alone  \
# 258  woman       False  NaN    Cherbourg   yes   True
# 737    man        True    B    Cherbourg   yes   True
# 679    man        True    B    Cherbourg   yes  False
# 341  woman       False    C  Southampton   yes  False
# 27     man        True    C  Southampton    no  False
# ..     ...         ...  ...          ...   ...    ...
# 806    man        True    A  Southampton    no   True
# 481    man        True  NaN  Southampton    no   True
# 597    man        True  NaN  Southampton    no   True
# 61   woman       False    B          NaN   yes   True
# 829  woman       False    B          NaN   yes   True
#
#                                                 ticket     price
# 258  Ticket: First; Price: $ 512.3292; Port: Cherbo...  512.3292
# 737  Ticket: First; Price: $ 512.3292; Port: Cherbo...  512.3292
# 679  Ticket: First; Price: $ 512.3292; Port: Cherbo...  512.3292
# 341  Ticket: First; Price: $ 263.0; Port: Southampton;  263.0000
# 27   Ticket: First; Price: $ 263.0; Port: Southampton;  263.0000
# ..                                                 ...       ...
# 806    Ticket: First; Price: $ 0.0; Port: Southampton;    0.0000
# 481   Ticket: Second; Price: $ 0.0; Port: Southampton;    0.0000
# 597    Ticket: Third; Price: $ 0.0; Port: Southampton;    0.0000
# 61                                                 NaN       NaN
# 829                                                NaN       NaN
#
# [891 rows x 17 columns]

# %%
# Out:
#                     0
#     match
# 27  0         $ 263.0
# 31  0      $ 146.5208
# 88  0         $ 263.0
# 118 0      $ 247.5208
# 195 0      $ 146.5208
